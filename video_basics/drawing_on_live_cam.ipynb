# %%
import cv2
cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

#top left corner 
x=width//2
y=height//2


#bottom right corner
w=width//4
h=height//4



while True:
    
    ret, frame = cap.read()
    
    # ** here note that the number system is not like coordinate system the y-axis is opposite direction
    cv2.rectangle(frame, (x,y), (x+w, y+h),color=(0,0,255), thickness=5 )
    
    cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# to interactively draw on a video follow the following code

# %%
import cv2
cap = cv2.VideoCapture(0)

# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# #top left corner 
# x=width//2
# y=height//2


# #bottom right corner
# w=width//4
# h=height//4

#call back function

def draw_rectangle(event, x,y,flags,params):
    global pt1,pt2, top_left_click, bottom_right_up
    if event==cv2.EVENT_LBUTTONDOWN:
        if top_left_click and bottom_right_up:
            #this is basically reset 
            top_left_click=False
            bottom_right_up=False
            pt1=(0,0)
            pt2=(0,0)
        if top_left_click==False :
            #first state
            top_left_click=True
            pt1=(x,y)
        elif bottom_right_up==False:
            pt2=(x,y)
            bottom_right_up=True
        # if top_left_click and not bottom_right_up:
        #     #you have to draw the rectange
        #     bottom_right_up=True
        #     pt2=(x,y)
        

#global variables
pt1=(0,0)
pt2=(0,0)
top_left_click=False
bottom_right_up=False

cap=cv2.VideoCapture(0)
cv2.namedWindow('test')
cv2.setMouseCallback('test', draw_rectangle)




while True:
    
    ret, frame = cap.read()
    
    # ** here note that the number system is not like coordinate system the y-axis is opposite direction
    #cv2.rectangle(frame, (x,y), (x+w, y+h),color=(0,0,255), thickness=5 )
    
    ##  drawing on the frame based of global variables
    
    if top_left_click:
        cv2.circle(frame, center=pt1, radius=5, color=(0,0,255), thickness=-1)
    if top_left_click and bottom_right_up:
        cv2.rectangle(frame, pt1, pt2,(0,0,255), thickness=4)
    
    cv2.imshow('test', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# #top left corner 
# x=width//2
# y=height//2


# #bottom right corner
# w=width//4
# h=height//4

#call back function

def draw_rectangle(event, x,y,flags,params):
    global pt1,pt2, top_left_click, bottom_right_up
    if event==cv2.EVENT_LBUTTONDBLCLK:
        if top_left_click and bottom_right_up:
            #this is basically reset 
            top_left_click=False
            bottom_right_up=False
            pt1=(0,0)
            pt2=(0,0)
        if not top_left_click and not bottom_right_up :
            #first state
            top_left_click=True
            pt1=(x,y)
        if top_left_click and not bottom_right_up:
            pt2=(x,y)
            bottom_right_up=True
        # if top_left_click and not bottom_right_up:
        #     #you have to draw the rectange
        #     bottom_right_up=True
        #     pt2=(x,y)
        

#global variables
pt1=(0,0)
pt2=(0,0)
top_left_click=False
bottom_right_up=False

cap=cv2.VideoCapture(0)
cv2.namedWindow('test')
cv2.setMouseCallback('test', draw_rectangle)




while True:
    
    ret, frame = cap.read()
    
    # ** here note that the number system is not like coordinate system the y-axis is opposite direction
    #cv2.rectangle(frame, (x,y), (x+w, y+h),color=(0,0,255), thickness=5 )
    
    ##  drawing on the frame based of global variables
    
    if top_left_click:
        cv2.circle(frame, center=pt1, radius=5, color=(0,0,255), thickness=-1)
    if top_left_click and bottom_right_up:
        cv2.rectangle(frame, pt1, pt2,(0,0,255), thickness=4)
    
    cv2.imshow('test', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
