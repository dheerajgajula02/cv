# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("../DATA/dog_backpack.jpg")
plt.imshow(img)

# %%
freshimg=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(freshimg)

# %%
plt.imshow(cv2.flip(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), -1))

# %%
plt.imshow(freshimg)

# %%
plt.imshow(cv2.rectangle(freshimg,(200,350), (600,800), color=(0,0,255), thickness=10))
