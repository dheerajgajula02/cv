# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread("../DATA/00-puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# ### even if we pass a wrong path we wont get an error instead we will get "None" type as output if we check the type of the output

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %% [markdown]
# matplot lib expects red->green->blue
# but open cv reads in blue->green->red   channeled image so they will get swapped hence we get this wierd colouration

# %%
plt.imshow(img)

# %%
fix_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
fix_image
# Out:
# array([[[95, 81, 78],
#         [97, 83, 80],
#         [98, 84, 81],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [96, 82, 79],
#         [96, 82, 79],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [94, 80, 77],
#         [94, 80, 77],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        ...,
#
#        [[19, 29, 20],
#         [20, 30, 21],
#         [20, 30, 21],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [20, 30, 21],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [19, 29, 20],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]]], dtype=uint8)

# %%
plt.imshow(fix_image)

# %%
print("this")
# Out:
# this
