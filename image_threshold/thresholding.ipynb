# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("../DATA/rainbow.jpg")

# %%
plt.imshow(img)

# %%
rough_img = img.copy()

# %%
rough_img=cv2.cvtColor(rough_img, cv2.COLOR_BGR2RGB)
plt.imshow(rough_img)

# %% [markdown]
# **to directly read as grey scale image syntax:**

# %%
gr_img = cv2.imread("../DATA/rainbow.jpg",0)
plt.imshow(gr_img, cmap='gray')

# %%
img.max()
# Out:
# 255

# %%
a=gr_img.max()

# %%
b=gr_img.min()

# %%
c=int(a+b)/2
# Out:
# C:\Users\dheer\AppData\Local\Temp/ipykernel_7876/281579628.py:1: RuntimeWarning: overflow encountered in ubyte_scalars
#   c=int(a+b)/2

# %%
# ret, thersh1=cv2.threshold(gr_img, c,a, cv2.THRESH_BINARY )
# Out:
# C:\Users\dheer\AppData\Local\Temp/ipykernel_7876/1224873320.py:1: RuntimeWarning: overflow encountered in ubyte_scalars
#   ret, thersh1=cv2.threshold(gr_img, int(a+b)/2,a, cv2.THRESH_BINARY )

# %%
# plt.imshow(thersh1, cmap='gray')

# %%
ret, thresh1 = cv2.threshold(gr_img, 127, 255, cv2.THRESH_BINARY)

# %% [markdown]
# **to get the inverse of this in place of THRESH_BINARY use THRESH_BINARY_INV**

# %%
plt.imshow(thresh1, cmap='gray')

# %%
ret
# Out:
# 127.0

# %%
ret2, thresh2 = cv2.threshold(gr_img, 127, 255, cv2.THRESH_TRUNC)

# %% [markdown]
# ### **read documentation for more ref, its nice**

# %%
plt.imshow(thresh2, cmap='gray')
